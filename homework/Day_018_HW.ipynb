# %% [markdown]
# # 作業 : (Kaggle)鐵達尼生存預測

# %% [markdown]
# # [作業目標]
# - 試著完成三種不同特徵類型的三種資料操作, 觀察結果
# - 思考一下, 這三種特徵類型, 哪一種應該最複雜/最難處理

# %% [markdown]
# # [作業重點]
# - 完成剩餘的八種 類型 x 操作組合 (In[6]~In[13], Out[6]~Out[13])
# - 思考何種特徵類型, 應該最複雜

# %%
# 載入基本套件
import pandas as pd
import numpy as np

# 讀取訓練與測試資料
# 設定 data_path
data_path = 'D:/GitHub/Data/Data1/'
df_train = pd.read_csv(data_path + 'titanic_train.csv')
df_test = pd.read_csv(data_path + 'titanic_test.csv')
df_train.shape
# Out:
# (891, 12)

# %%
df_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# 重組資料成為訓練 / 預測用格式
train_Y = df_train['Survived']
ids = df_test['PassengerId']
df_train = df_train.drop(['PassengerId', 'Survived'] , axis=1)
df_test = df_test.drop(['PassengerId'] , axis=1)
df = pd.concat([df_train,df_test])
df.head()
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S
# 4      0      0            373450   8.0500   NaN        S

# %%
# 秀出資料欄位的類型與數量
dtype_df = df.dtypes.reset_index()
dtype_df.columns = ["Count", "Column Type"]
dtype_df = dtype_df.groupby("Column Type").aggregate('count').reset_index()
dtype_df
# Out:
#   Column Type  Count
# 0       int64      3
# 1     float64      2
# 2      object      5

# %%
#確定只有 int64, float64, object 三種類型後, 分別將欄位名稱存於三個 list 中
int_features = []
float_features = []
object_features = []
for dtype, feature in zip(df.dtypes, df.columns):
    if dtype == 'float64':
        float_features.append(feature)
    elif dtype == 'int64':
        int_features.append(feature)
    else:
        object_features.append(feature)
print(f'{len(int_features)} Integer Features : {int_features}\n')
print(f'{len(float_features)} Float Features : {float_features}\n')
print(f'{len(object_features)} Object Features : {object_features}')
# Out:
# 3 Integer Features : ['Pclass', 'SibSp', 'Parch']
#
# 2 Float Features : ['Age', 'Fare']
#
# 5 Object Features : ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %% [markdown]
# # 作業1
# * 試著執行作業程式，觀察三種類型 (int / float / object) 的欄位分別進行( 平均 mean / 最大值 Max / 相異值 nunique )
# 中的九次操作會有那些問題? 並試著解釋那些發生Error的程式區塊的原因?
#
# # 作業2
# * 思考一下，試著舉出今天五種類型以外的一種或多種資料類型，你舉出的新類型是否可以歸在三大類中的某些大類?
# 所以三大類特徵中，哪一大類處理起來應該最複雜?

# %%
## H1
## Error 是因為非數值型的無法做數學計算

## H2
## Ans:String
# Out:
# ====== int =====
# Pclass    2.294882
# SibSp     0.498854
# Parch     0.385027
# dtype: float64
# Pclass    3
# SibSp     8
# Parch     9
# dtype: int64
# Pclass    1
# SibSp     0
# Parch     0
# dtype: int64
# ====== float =====
# Age     29.881138
# Fare    33.295479
# dtype: float64
# Age      80.0000
# Fare    512.3292
# dtype: float64
# Age     0.17
# Fare    0.00
# dtype: float64
# ====== objective =====
# Series([], dtype: float64)
# Name      van Melkebeke, Mr. Philemon
# Sex                              male
# Ticket                      WE/P 5735
# dtype: object
# Name      Abbing, Mr. Anthony
# Sex                    female
# Ticket                 110152
# dtype: object

# %%
df[int_features]
# Out:
#      Pclass  SibSp  Parch
# 0         3      1      0
# 1         1      1      0
# 2         3      0      0
# 3         1      1      0
# 4         3      0      0
# 5         3      0      0
# 6         1      0      0
# 7         3      3      1
# 8         3      0      2
# 9         2      1      0
# 10        3      1      1
# 11        1      0      0
# 12        3      0      0
# 13        3      1      5
# 14        3      0      0
# 15        2      0      0
# 16        3      4      1
# 17        2      0      0
# 18        3      1      0
# 19        3      0      0
# 20        2      0      0
# 21        2      0      0
# 22        3      0      0
# 23        1      0      0
# 24        3      3      1
# 25        3      1      5
# 26        3      0      0
# 27        1      3      2
# 28        3      0      0
# 29        3      0      0
# ..      ...    ...    ...
# 388       3      0      0
# 389       3      3      1
# 390       1      0      0
# ...

# %%
# 請依序列出 三種特徵類型 (int / float / object) x 三種方法 (平均 mean / 最大值 Max / 相異值 nunique) 的其餘操作
"""
Your Code Here
"""
print("====== mean =====")
print(df[int_features][len(df[int_features].columns):].mean())
print("====== max =====")
print(df[int_features][len(df[int_features].columns):].max()) 
print("====== min =====")
print(df[int_features][len(df[int_features].columns):].min()) 

for i in df[int_features]:
    print("----------------------------")
    print(i)
    print(df[int_features][i].max())
    print(df[int_features][i].min())
    print(df[int_features][i].mean()) 
    print(df[int_features][i].unique()) 
    print("----------------------------")
# Out:
# ====== mean =====
# Pclass    2.294793
# SibSp     0.498469
# Parch     0.385911
# dtype: float64
# ====== max =====
# Pclass    3
# SibSp     8
# Parch     9
# dtype: int64
# ====== min =====
# Pclass    1
# SibSp     0
# Parch     0
# dtype: int64
# ----------------------------
# Pclass
# 3
# 1
# 2.294881588999236
# [3 1 2]
# ----------------------------
# ----------------------------
# SibSp
# 8
# 0
# 0.4988540870893812
# [1 0 3 4 2 5 8]
# ----------------------------
# ----------------------------
# Parch
# 9
# 0
# 0.3850267379679144
# [0 1 2 5 3 4 6 9]
# ----------------------------

# %%
print("====== mean =====")
print(df[float_features][len(df[float_features].columns):].mean())
print("====== max =====")
print(df[float_features][len(df[float_features].columns):].max()) 
print("====== min =====")
print(df[float_features][len(df[float_features].columns):].min()) 

for i in df[float_features]:
    print("----------------------------")
    print(i)
    print(df[float_features][i].unique()) 
    print(df[float_features][i].max())
    print(df[float_features][i].min())
    print(df[float_features][i].mean()) 
    
    print("----------------------------")
# Out:
# ====== mean =====
# Age     29.880910
# Fare    33.286335
# dtype: float64
# ====== max =====
# Age      80.0000
# Fare    512.3292
# dtype: float64
# ====== min =====
# Age     0.17
# Fare    0.00
# dtype: float64
# ----------------------------
# Age
# [ 22.    38.    26.    35.      nan  54.     2.    27.    14.     4.    58.
#   20.    39.    55.    31.    34.    15.    28.     8.    19.    40.    66.
#   42.    21.    18.     3.     7.    49.    29.    65.    28.5    5.    11.
#   45.    17.    32.    16.    25.     0.83  30.    33.    23.    24.    46.
#   59.    71.    37.    47.    14.5   70.5   32.5   12.     9.    36.5   51.
#   55.5   40.5   44.     1.    61.    56.    50.    36.    45.5   20.5   62.
#   41.    52.    63.    23.5    0.92  43.    60.    10.    64.    13.    48.
#    0.75  53.    57.    80.    70.    24.5    6.     0.67  30.5    0.42
#   34.5   74.    22.5   18.5   67.    76.    26.5   60.5   11.5    0.33
#    0.17  38.5 ]
# 80.0
# 0.17
# 29.881137667304014
# ...

# %%
print("====== mean =====")
print(df[object_features][len(df[object_features].columns):].mean())
print("====== max =====")
print(df[object_features][len(df[object_features].columns):].max()) 
print("====== min =====")
print(df[object_features][len(df[object_features].columns):].min()) 

for i in df[object_features]:
    print("----------------------------")
    print(i)
    print(df[object_features][i].unique()) 
    print(";;;")
    print(df[object_features][i].max())
    print(df[object_features][i].min())
    print(df[object_features][i].mean()) 
  
    print("----------------------------")
# Out:
# ====== mean =====
# Series([], dtype: float64)
# ====== max =====
# Name      van Melkebeke, Mr. Philemon
# Sex                              male
# Ticket                      WE/P 5735
# dtype: object
# ====== min =====
# Name      Abbing, Mr. Anthony
# Sex                    female
# Ticket                 110152
# dtype: object
# ----------------------------
# Name
# ['Braund, Mr. Owen Harris'
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'
#  'Heikkinen, Miss. Laina' ..., 'Saether, Mr. Simon Sivertsen'
#  'Ware, Mr. Frederick' 'Peter, Master. Michael J']
# ;;;
# van Melkebeke, Mr. Philemon
# Abbing, Mr. Anthony
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\awei.lin\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#     767         try:
# --> 768             x = float(x)
#     769         except Exception:
# ...

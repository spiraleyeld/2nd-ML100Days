# 4988         -73.991157         40.731852                6         2012
# 4989         -73.965067         40.755190                5         2013
# 4990         -73.989997         40.751650                1         2012
# 4991         -73.995768         40.726276                1         2009
# 4992         -73.973613         40.750718                1         2014
# 4993         -73.981157         40.737545                1         2014
# 4994         -73.976149         40.782166                1         2009
# 4995         -73.986840         40.759202                1         2011
# 4996         -73.977022         40.726482                1         2009
# 4997         -73.995004         40.750059                1         2010
# 4998         -73.953445         40.782598                1         2010
# 4999         -73.991758         40.744213                4         2009
#
#       pickup_month  pickup_day  pickup_hour  pickup_minute  pickup_second  \
# 0               10          21           23             54             10
# 1                2           3           10             42              3
# 2                3          16           18             58             58
# 3                6          13           16             10             54
# 4                6          12            3             25             56
# 5                7          16            1             19             59
# 6                6          27           18             15              0
# 7                1          23           20             38             16
# 8                8           9           14             46              3
# 9                9          29           21             56             45
# 10               2           9           22             26              0
# 11              11           3           21              7              0
# 12              11          23            5             18              0
# 13               4           2           21              8              2
# 14              12          14           20             28             45
# 15               3          30            1             52             38
# 16               7           1            3             24             53
# 17               8           1            1              0             25
# 18               3          17           10             39              5
# 19              11           1           20             41              0
# 20               4          21           17             48             35
# 21               1           7           17             53              0
# 22               6          16           15              6              0
# 23               3           5           20             25              0
# 24              10           8            9              9             39
# 25               5          21           18             46              0
# 26               2          11           21             21              0
# 27               7           9           23             12              0
# 28              12          14           12              3             14
# 29               2          12           12              9             15
# ...            ...         ...          ...            ...            ...
# 4970             7          14           21             36              0
# 4971             3          24           21             15             30
# 4972             2          21           21              9              0
# 4973            10          28            3             46             39
# 4974             9          12           22             28             17
# 4975             7          18           10             51             22
# 4976             8          12           10             20              0
# 4977            12           3           11             21             47
# 4978            10           3           13              8              0
# 4979             5           1           23              7              0
# 4980             2           7           20             28             46
# 4981            10          24           14              9              0
# 4982             3          16           20             21             31
# 4983             7          27           10             43             46
# 4984             2           6           11             58             46
# 4985            12          20            2             11              0
# 4986             2           1           13             33             17
# 4987            12          18           18              3             46
# 4988            11           5           14             58              0
# 4989            12          24           18             36              0
# 4990            12           2           12             21             13
# 4991             4          11           19             24             50
# 4992            12           1           19             59             19
# 4993             9          29           18             59              0
# 4994             8          13           14             16             40
# 4995            12          23           19              7              0
# 4996             8          26           18             19             41
# 4997            10          25            6              5             21
# 4998             2          16           16             57              0
# 4999             2          18           17              1              5
#
#       pickup_weekday
# 0                  5
# 1                  2
# 2                  0
# 3                  6
# 4                  4
# 5                  6
# 6                  6
# 7                  5
# 8                  1
# 9                  4
# 10                 1
# 11                 3
# 12                 1
# 13                 1
# 14                 1
# 15                 0
# 16                 3
# 17                 4
# 18                 6
# 19                 5
# 20                 1
# 21                 6
# 22                 4
# 23                 6
# 24                 1
# 25                 3
# 26                 2
# 27                 6
# 28                 3
# 29                 0
# ...              ...
# 4970               6
# 4971               2
# 4972               1
# 4973               0
# 4974               4
# 4975               0
# 4976               3
# 4977               5
# 4978               6
# 4979               5
# 4980               6
# 4981               1
# 4982               1
# 4983               3
# 4984               0
# 4985               5
# 4986               6
# 4987               5
# 4988               1
# 4989               2
# 4990               0
# 4991               6
# 4992               1
# 4993               1
# 4994               4
# 4995               5
# 4996               3
# 4997               1
# 4998               2
# 4999               3
#
# [5000 rows x 13 columns]

# %%
# 將結果使用線性迴歸 / 梯度提升樹分別看結果
df_temp = df.drop(['pickup_datetime'] , axis=1)
scaler = MinMaxScaler()
train_X = scaler.fit_transform(df_temp)
Linear = LinearRegression()
print(f'Linear Reg Score : {cross_val_score(Linear, train_X, train_Y, cv=5).mean()}')
GDBT = GradientBoostingRegressor()
print(f'Gradient Boosting Reg Score : {cross_val_score(GDBT, train_X, train_Y, cv=5).mean()}')
# Out:
# Linear Reg Score : 0.02677831475863668
# Gradient Boosting Reg Score : 0.7111891757336312

# %% [markdown]
# # 作業1
# * 對照範例，試著加入星期幾 (day of week) 與第幾周 (week of year) 這兩項特徵，
# 看看結果會比原本只有時間特徵分解的結果更好或更差?

# %%
# 加入星期幾與第幾周兩個特徵
"""
Your Code Here
"""
# 時間特徵分解方式:使用datetime
df['pickup_weekday'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strftime(x, '%w')).astype('int64')
df['pickup_weekTH'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strftime(x, '%U')).astype('int64')
 
 
df.head()
# Out:
#       pickup_datetime  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0 2011-10-21 23:54:10        -73.990580        40.761071         -73.981128
# 1 2015-02-03 10:42:03        -73.988403        40.723431         -73.989647
# 2 2014-03-16 18:58:58        -74.015785        40.715110         -74.012029
# 3 2009-06-13 16:10:54        -73.977322        40.787275         -73.958030
# 4 2014-06-12 03:25:56        -73.989683        40.729717         -73.982490
#
#    dropoff_latitude  passenger_count  pickup_year  pickup_month  pickup_day  \
# 0         40.758634                2         2011            10          21
# 1         40.741695                1         2015             2           3
# 2         40.707888                2         2014             3          16
# 3         40.778838                3         2009             6          13
# 4         40.761887                3         2014             6          12
#
#    pickup_hour  pickup_minute  pickup_second  pickup_weekday  pickup_weekTH
# 0           23             54             10               5             42
# 1           10             42              3               2              5
# 2           18             58             58               0             11
# 3           16             10             54               6             23
# 4            3             25             56               4             23

# %%
# 將結果使用線性迴歸 / 梯度提升樹分別看結果
df_temp = df.drop(['pickup_datetime'] , axis=1)
train_X = scaler.fit_transform(df_temp)
print(f'Linear Reg Score : {cross_val_score(Linear, train_X, train_Y, cv=5).mean()}')
print(f'Gradient Boosting Reg Score : {cross_val_score(GDBT, train_X, train_Y, cv=5).mean()}')
# Out:
# Linear Reg Score : 0.028722639911798863
# Gradient Boosting Reg Score : 0.7115713150167322

# %%
# 加上"日週期"特徵 (參考講義"週期循環特徵")
import math
df['day_cycle'] = df['pickup_hour']/12 + df['pickup_minute']/720 + df['pickup_second']/43200
df['day_cycle'] = df['day_cycle'].map(lambda x:math.sin(x*math.pi))
df.head()
# Out:
#       pickup_datetime  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0 2011-10-21 23:54:10        -73.990580        40.761071         -73.981128
# 1 2015-02-03 10:42:03        -73.988403        40.723431         -73.989647
# 2 2014-03-16 18:58:58        -74.015785        40.715110         -74.012029
# 3 2009-06-13 16:10:54        -73.977322        40.787275         -73.958030
# 4 2014-06-12 03:25:56        -73.989683        40.729717         -73.982490
#
#    dropoff_latitude  passenger_count  pickup_year  pickup_month  pickup_day  \
# 0         40.758634                2         2011            10          21
# 1         40.741695                1         2015             2           3
# 2         40.707888                2         2014             3          16
# 3         40.778838                3         2009             6          13
# 4         40.761887                3         2014             6          12
#
#    pickup_hour  pickup_minute  pickup_second  pickup_weekday  pickup_weekTH  \
# 0           23             54             10               5             42
# 1           10             42              3               2              5
# 2           18             58             58               0             11
# 3           16             10             54               6             23
# 4            3             25             56               4             23
#
#    day_cycle
# 0  -0.025450
# 1   0.333601
# 2  -0.967083
# 3  -0.888817
# 4   0.782427

# %%
# 將結果使用線性迴歸 / 梯度提升樹分別看結果
df_temp = df.drop(['pickup_datetime'] , axis=1)
train_X = scaler.fit_transform(df_temp)
print(f'Linear Reg Score : {cross_val_score(Linear, train_X, train_Y, cv=5).mean()}')
print(f'Gradient Boosting Reg Score : {cross_val_score(GDBT, train_X, train_Y, cv=5).mean()}')
# Out:
# Linear Reg Score : 0.028234094061824
# Gradient Boosting Reg Score : 0.7115351310884559

# %% [markdown]
# # 作業2
# * 對照範例的日週期效果，試著參考投影片完成年週期與周週期的特徵 (也可以用你自己想到的方式)，
# 看看結果會比範例中的結果更好或更差?

# %%
# 加上"年週期"與"周週期"特徵
"""
Your Code Here
"""

df['year_cycle'] = df['pickup_month']/6 + df['pickup_day']/180
df['year_cycle'] = df['day_cycle'].map(lambda x:math.cos(x*math.pi))
df.head()
# Out:
#       pickup_datetime  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0 2011-10-21 23:54:10        -73.990580        40.761071         -73.981128
# 1 2015-02-03 10:42:03        -73.988403        40.723431         -73.989647
# 2 2014-03-16 18:58:58        -74.015785        40.715110         -74.012029
# 3 2009-06-13 16:10:54        -73.977322        40.787275         -73.958030
# 4 2014-06-12 03:25:56        -73.989683        40.729717         -73.982490
#
#    dropoff_latitude  passenger_count  pickup_year  pickup_month  pickup_day  \
# 0         40.758634                2         2011            10          21
# 1         40.741695                1         2015             2           3
# 2         40.707888                2         2014             3          16
# 3         40.778838                3         2009             6          13
# 4         40.761887                3         2014             6          12
#
#    pickup_hour  pickup_minute  pickup_second  pickup_weekday  pickup_weekTH  \
# 0           23             54             10               5             42
# 1           10             42              3               2              5
# 2           18             58             58               0             11
# 3           16             10             54               6             23
# 4            3             25             56               4             23
#
#    day_cycle  year_cycle
# 0  -0.025450    0.996805
# 1   0.333601    0.499271
# 2  -0.967083   -0.994658
# 3  -0.888817   -0.939616
# 4   0.782427   -0.775351

# %%
df['week_cycle'] = df['pickup_weekday']/3.5 + df['pickup_hour']/84
df['week_cycle'] = df['week_cycle'].map(lambda x:math.sin(x*math.pi))
df.head()
# Out:
#       pickup_datetime  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0 2011-10-21 23:54:10        -73.990580        40.761071         -73.981128
# 1 2015-02-03 10:42:03        -73.988403        40.723431         -73.989647
# 2 2014-03-16 18:58:58        -74.015785        40.715110         -74.012029
# 3 2009-06-13 16:10:54        -73.977322        40.787275         -73.958030
# 4 2014-06-12 03:25:56        -73.989683        40.729717         -73.982490
#
#    dropoff_latitude  passenger_count  pickup_year  pickup_month  pickup_day  \
# 0         40.758634                2         2011            10          21
# 1         40.741695                1         2015             2           3
# 2         40.707888                2         2014             3          16
# 3         40.778838                3         2009             6          13
# 4         40.761887                3         2014             6          12
#
#    pickup_hour  pickup_minute  pickup_second  pickup_weekday  pickup_weekTH  \
# 0           23             54             10               5             42
# 1           10             42              3               2              5
# 2           18             58             58               0             11
# 3           16             10             54               6             23
# 4            3             25             56               4             23
#
#    day_cycle  year_cycle  week_cycle
# 0  -0.025450    0.996805   -0.804598
# 1   0.333601    0.499271    0.826239
# 2  -0.967083   -0.994658    0.623490
# 3  -0.888817   -0.939616   -0.294755
# 4   0.782427   -0.775351   -0.532032

# %%
df.head()
# Out:
#       pickup_datetime  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0 2011-10-21 23:54:10        -73.990580        40.761071         -73.981128
# 1 2015-02-03 10:42:03        -73.988403        40.723431         -73.989647
# 2 2014-03-16 18:58:58        -74.015785        40.715110         -74.012029
# 3 2009-06-13 16:10:54        -73.977322        40.787275         -73.958030
# 4 2014-06-12 03:25:56        -73.989683        40.729717         -73.982490
#
#    dropoff_latitude  passenger_count  pickup_year  pickup_month  pickup_day  \
# 0         40.758634                2         2011            10          21
# 1         40.741695                1         2015             2           3
# 2         40.707888                2         2014             3          16
# 3         40.778838                3         2009             6          13
# 4         40.761887                3         2014             6          12
#
#    pickup_hour  pickup_minute  pickup_second  pickup_weekday  pickup_weekTH  \
# 0           23             54             10               5             42
# 1           10             42              3               2              5
# 2           18             58             58               0             11
# 3           16             10             54               6             23
# 4            3             25             56               4             23
#
#    day_cycle
# 0  -0.025450
# 1   0.333601
# 2  -0.967083
# 3  -0.888817
# 4   0.782427

# %%
# 將結果使用線性迴歸 / 梯度提升樹分別看結果
df_temp = df.drop(['pickup_datetime'] , axis=1)
train_X = scaler.fit_transform(df_temp)
print(f'Linear Reg Score : {cross_val_score(Linear, train_X, train_Y, cv=5).mean()}')
print(f'Gradient Boosting Reg Score : {cross_val_score(GDBT, train_X, train_Y, cv=5).mean()}')
# Out:
# Linear Reg Score : 0.03002208280783645
# Gradient Boosting Reg Score : 0.7055727439600941

# %%
abc = 1

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math


w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)
x_lin = np.array(x_lin,  dtype=np.int32 )

y = ((x_lin + (np.random.randn(101) * 5)) * w) + b
y = np.array(y,  dtype=np.int32 )
print(y)
print(y**2)
 
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

y_hat = x_lin * w + b
y_hat = np.array(y_hat,dtype=np.int32 )
print(y_hat)
print(y_hat**2)

plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

def mean_squared_error(ActualArrany, PredictArray):  
    MainArray =(ActualArrany - PredictArray)
    MainArray = np.array(MainArray,  dtype=np.int32 )
    #print(ActualArrany)
    #print(PredictArray)
    #print(MainArray)
    
    MainArray = MainArray**2
    #print(MainArray)
    
    #print(MainArray.sum() )
    ArrayCounter = np.size(MainArray)
    #print(ArrayCounter)
    MSE = MainArray.sum() / ArrayCounter

    return MSE

def mean_absolute_error(ActualArrany, PredictArray):  
    MainArray = abs(ActualArrany - PredictArray)
    MainArray = np.array(MainArray,  dtype=np.int32 )
    ArrayCounter = np.size(MainArray)
    MAE = MainArray.sum() / ArrayCounter
  
    return MAE

# 執行 Function, 確認有沒有正常執行 
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# [ 21  23  -5 -22  22  17  48  21   0  45  17  16  59  30  34  52  53  74
#   61  51  60  57  90  81  80  70  59  87 108 108  89  85 100 121 103 110
#  113 119 105 128 124 137 134 133 141 139 124 143 150 127 172 137 143 168
#  170 151 159 165 160 186 189 188 187 192 209 191 198 187 193 206 210 221
#  231 219 227 238 233 249 246 243 255 236 252 257 244 244 274 270 279 252
#  264 269 283 263 291 301 279 319 308 288 292]
# [   441    529     25    484    484    289   2304    441      0   2025
#     289    256   3481    900   1156   2704   2809   5476   3721   2601
#    3600   3249   8100   6561   6400   4900   3481   7569  11664  11664
#    7921   7225  10000  14641  10609  12100  12769  14161  11025  16384
#   15376  18769  17956  17689  19881  19321  15376  20449  22500  16129
#   29584  18769  20449  28224  28900  22801  25281  27225  25600  34596
#   35721  35344  34969  36864  43681  36481  39204  34969  37249  42436
# ...

# %%
# 作業1：

# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：


# 1. 你選的這組資料為何重要
# Ans: Titanic: Machine Learning from Disaster :資料內容很完整，分析目的很清楚
 
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# Ans: Kaggle競賽

# 3. 蒐集而來的資料型態為何
# Ans: Excel 檔案

# 4. 這組資料想解決的問題如何評估
# Ans: 解決誰最容易生存

# %%
# 作業2：

# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# Ans: 提升載客率


# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# Ans: 已發的叫車交易紀錄，欄位有客人的年齡範圍，性別，上下車點，車資，乘車路線，乘車時間


# 3. 蒐集而來的資料型態為何
# Ans: 結構化的電子數據


# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# Ans: 每天的實際載客人數 / 每天的預估載客人數 (hit rate)
